# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import sklearn as sk

# %%
data = [7, 4, 73, 34, 65, 85, 97, 68, 23, 16, 15, 19, 10]
data2 = [96, 34, 34, 34 ,56 ,573 ,56, 53,7,89, 87,34 ,754]

# %%
excelData = pd.read_excel("PBBSC-EXCEL EXERCISE.xlsx")
csvData = pd.read_csv("C:/Users/mca/Lab1/TEST.csv")
mydata = pd.DataFrame(data)
mydata
# Out:
#      0
# 0    7
# 1    4
# 2   73
# 3   34
# 4   65
# 5   85
# 6   97
# 7   68
# 8   23
# 9   16
# 10  15
# 11  19
# 12  10

# %%
for value in mydata:
    print(mydata[value])
# Out:
# 0      7
# 1      4
# 2     73
# 3     34
# 4     65
# 5     85
# 6     97
# 7     68
# 8     23
# 9     16
# 10    15
# 11    19
# 12    10
# Name: 0, dtype: int64

# %%
print(mydata.head())
print(mydata.tail())
# Out:
#     0
# 0   7
# 1   4
# 2  73
# 3  34
# 4  65
#      0
# 8   23
# 9   16
# 10  15
# 11  19
# 12  10

# %%
print(mydata.loc[2:5])
print(mydata.loc[(mydata[0] > 7) & (mydata[0] < 50)])
# Out:
#     0
# 2  73
# 3  34
# 4  65
# 5  85
#      0
# 3   34
# 8   23
# 9   16
# 10  15
# 11  19
# 12  10

# %%
print(np.max(mydata[0]))
print(np.mean(mydata[0]))
print(np.median(mydata[0]))
# Out:
# 97
# 39.69230769230769
# 23.0

# %%
plt.plot(data, data2)

# %%
excelData
# Out:
#                                                   Q1)   Unnamed: 1  \
# 0   This exercise in Microsoft Excel consists of a...          NaN
# 1                                              Gender  Age (Years)
# 2                                                   M           21
# 3                                                   F           26
# 4                                                   M           30
# 5                                                   M           28
# 6                                                   M           27
# 7                                                   M           21
# 8                                                   F           29
# 9                                                   M           26
# 10                                                  M           24
# 11                                                  M           28
# 12                                                  M           29
# ...

# %%
csvData.loc[1:3]
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                   MY KUMAN             Mark
# 3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
#
#           Description  Leave
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2

# %%
csvData.loc[csvData['Leave'] >= 1]
# Out:
#     Serial Number                                       Company Name  \
# 3   9780007880331                            THE GOD OF SMAAL THINGS
# 12  9788187776013                       MarkLANDA VISHAL SHABD SAGAR
# 14  9789384716165  LIEUTEMarkMarkT GENERAL BHAGAT: A SAGA OF BRAV...
# 16  9789384850319                                     I AM KRISHMark
# 19  9789384850746                                 SECRETS OF DESTINY
# 20  9789384850753        BHAGYA KE RAHASYA (HINDI) SECRET OF DESTINY
# 24  9780349123462                               IN SPITE OF THE GODS
# 25  9788188440061           QUESTIONS & ANWERS ABOUT THE GREAT BIBLE
# 26  9789382088189               NIBANDH EVAM KAHANI LEKHAN { HINDI }
# 27  9789332703759          INDIAN ECONOMY SINCE INDEPENDENCE 27TH /E
# 28  9788171888016           ECONOMIC DEVELOPMENT AND POLICY IN INDIA
# 29  9789332704343       INDIAN ECONOMY PERFORMANCE 18TH/E  2017-2018
# 30  9789332703735  INDIAN ECONOMIC DEVELOPMENTSINCE 1947 (NO RETU...
# ...

# %%
plt.plot(csvData['Description'])

# %%
csvData.loc[csvData['Description'] == 'ACCESS PUBLISHING INDIA PVT.LTD']
# Out:
#     Serial Number                                       Company Name  \
# 31  9789383454143  PRELIMS SPECIAL READING COMPREHENSION PAPER II...
# 32  9789383454204                  THE CONSTITUTION OF INDIA 2ND / E
# 33  9789386361011                     INDIAN HERITAGE ,ART & CULTURE
# 34  9789383454303                                BHARAT KA SAMVIDHAN
# 35  9789383454471              ETHICS, INTEGRITY & APTITUDE ( 3RD/E)
# 36  9789383454563                  GENERAL STUDIES PAPER -- I (2016)
# 37  9789383454570                  GENERAL STUDIES PAPER - II (2016)
# 38  9789383454693                      INDIAN AND WORLD GEOGRAPHY 2E
# 39  9789383454709      VASTUNISTHA PRASHN SANGRAHA: BHARAT KA ITIHAS
# 40  9789383454723             PHYSICAL, HUMAN AND ECONOMIC GEOGRAPHY
# 41  9789383454730                                    WORLD GEOGRAPHY
# 42  9789383454822                    INDIA: MAP ENTRIES IN GEOGRAPHY
# 43  9789383454853                   GOOD GOVERMarkNCE IN INDIA 2/ED.
# ...
