# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import datetime as dt
import seaborn as sns
from textblob import TextBlob

df = pd.read_csv('amazon_baby.csv')
df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %%
# Question 1

values = df['name'].str.strip().value_counts(ascending=False)
values
# Out:
# Vulli Sophie the Giraffe Teether                                                                                                                                                                                                                                                                                                                       779
# Simple Wishes Hands-Free Breastpump Bra, Pink, XS-L                                                                                                                                                                                                                                                                                                    560
# ...

# %%
# Question 2

values = df['name'].str.strip().value_counts(ascending=False)
print('Products with more than 15 reviews:',(values > 15).count())
# Out:
# Products with more than 15 reviews: 32315

# %%
# Question 5

df['polarity'] = df['review'].map(lambda text: TextBlob(text).sentiment.polarity)
df['review_len'] = df['review'].astype(str).apply(len)
df['word_count'] = df['review'].apply(lambda x: len(str(x).split()))
df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  review_len  \
# 0  These flannel wipes are OK, but in my opinion ...       3         452
# 1  it came early and was not disappointed. i love...       5         158
# 2  Very soft and comfortable and warmer than it l...       5         143
# 3  This is a product well worth the purchase.  I ...       5         390
# 4  All of my kids have cried non-stop when I trie...       5         405
#
#    word_count  polarity
# 0          79  0.083333
# 1          30  0.367000
# 2          23  0.293333
# 3          74  0.318767
# 4          76  0.803299

# %%
# Question 6

df['polarity'].plot(kind='hist',title='Sentiment Polarity Distribution')
# Out:
# <AxesSubplot:title={'center':'Sentiment Polarity Distribution'}, ylabel='Frequency'>

# %%
# Question 7
df['rating'].plot(kind='hist',title='Review Rating Distribution')
# Out:
# <AxesSubplot:title={'center':'Review Rating Distribution'}, ylabel='Frequency'>

# %%
# Question 8

values = df['rating'].value_counts(ascending=False)
values
# Out:
# 5    106265
# 4     33053
# 3     16705
# 1     15100
# 2     11261
# Name: rating, dtype: int64

# %%
# Question 9

df.nlargest(20, ['polarity'])
# Out:
#                                                    name  \
# 442                             Baby Trend Diaper Champ
# 1213  Thomas &amp; Friends - 3 Piece Dinnerware Set-...
# 2153                   Philips Avent 3 Pack 9oz Bottles
# 2314  Prince Lionheart Table Edge Guard with 4 Corne...
# 2366  Prince Lionheart Table Edge Guard with 4 Corne...
# 3149      Sunshine Kids Mighty Tite Seat Belt Tightener
# 3183  Neat Solutions Sesame Street Table Topper Disp...
# 3200  Playtex Drop-Ins Pre-Sterilized Soft Bottle Li...
# 3243          Medela Breastmilk Storage and Feeding Set
# 3309               Prince Lionheart Crib Rail Protector
# 3466  Philips Avent Express Baby Food and Bottle Warmer
# 4100                    The First Years Hands Free Gate
# 4131                    The First Years Hands Free Gate
# 4307     Philips AVENT Comfort Breast Shell Set, 2-Pack
# 4356    SoftShells Breast Shell Soothers - Sore Nipples
# 5215  The First Years Babypro Quick Serve Bottle War...
# ...

# %%
# Question 10

print('correlation between review length and rating', df.rating.corr(df.review_len))
# Out:
# correlation between review length and rating -0.08423591551712209

# %%
# Question 11

import re
import unicodedata
import nltk
from nltk.corpus import stopwords


(pd.Series(nltk.ngrams(words, 1)).value_counts())[:25]
(pd.Series(nltk.ngrams(words, 2)).value_counts())[:25]
(pd.Series(nltk.ngrams(words, 3)).value_counts())[:25]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10197/4286343971.py in <module>
#       6 from nltk.corpus import stopwords
#       7
# ----> 8 (pd.Series(nltk.ngrams(words, 1)).value_counts())[:25]
#       9 (pd.Series(nltk.ngrams(words, 2)).value_counts())[:25]
#      10 (pd.Series(nltk.ngrams(words, 3)).value_counts())[:25]
#
# NameError: name 'words' is not defined

# %%
# Data Pre-processing and text cleaning - Question 3, 4
contractions={"a'ight":"alright",
"ain't":"are not",
"amn't":"am not",
"can't":"cannot",
"'cause": "because",
"could've":"could have",
"couldn't":"could not",
"couldn't've":"could not have",
"daren't":"dare not",
"daresn't":"dare not",
"dasn't":"dare not",
"didn't":"did not",
"doesn't":"does not",
"don't":"do not",
"everybody's":"everybody is",
"everyone's":"everyone is",
"giv'n":"given",
"gonna":"going to",
"gon't":"go not", 
"gotta":"got to",
"hadn't":"had not",
"had've":"had have",
"hasn't":"has not",
"haven't":"have not",
"he'd":	"he had", 
"he'll":"he will",
"he's":	"he is",
"here's":"here is",
"how'd":"how did",
"how'll":"how will",
"how're":"how are",
"how's":"how is",
"I'd":"I had",
"I'd've":"I would have",
"I'd'nt":"I would not",
"I'd'nt've":"I would not have",
"I'll":"I will",
"I'm":"I am",
"I've":"I have",
"isn't":"is not",
"it'd":"it would",
"it'll":"it will",
"it's":	"it is",
"let's":"let us",
"ma'am":"madam",
"mayn't":"may not",
"may've":"may have",
"mightn't":"might not",
"might've":"might have",
"mustn't":"must not",
"mustn't've":"must not have",
"must've":"must have",
"needn't":"need not",
"needn't've":"need not have",
"o'clock":"of the clock",
"oughtn't":"ought not",
"oughtn't've":"ought not have",
"shan't":"shall not",
"she'd":"she would",
"she'll":"she will",
"she's":"she is",
"should've":"should have",
"shouldn't":"should not",
"shouldn't've":"should not have",
"somebody's":"somebody is",
"someone's":"someone is",
"something's":"something is",
"so're":"so are",
"so’s":"so is",
"so’ve":"so have",
"that'll":"that will",
"that're":"that are",
"that's":"that is",
"that'd":"that would",
"there'd":"there would",
"there'll":"there will",
"there're":"there are",
"there's":"there is",
"these're":"these are",
"these've":"these have",
"they'd":"they would",
"they'll":"they will",
"they're":"they are",
"they've":"they have",
"this's":"this is",
"those're":"those are",
"those've":"those have",
"to've":"to have",
"wasn't":"was not",
"we'd":	"we would",
"we'd've":"we would have",
"we'll":"we will",
"we're":"we are",
"we've":"we have",
"weren't":"were not",
"what'd":"what did",
"what'll":"what will",
"what're":"what are",
"what's":"what is",
"what've":"what have",
"when's":"when is",
"where'd":"where did",
"where'll":"where will",
"where're":"where are",
"where's":"where is",
"where've":"where have",
"which'd":"which would",
"which'll":"which will",
"which're":"which are",
"which's":"which is",
"which've":"which have",
"who'd":"who would",
"who'd've":"who would have",
"who'll":"who will",
"who're":"who are",
"who's":"who is",
"who've":"who have",
"why'd":"why did",
"why're":"why are",
"why's":"why is",
"won't":"will not",
"would've":"would have",
"wouldn't":"would not",
"wouldn't've":"would not have",
"y'at":	"you at",
"yes’m":"yes madam",
"you'd":"you would",
"you'll":"you will",
"you're":"you are",
"you've":"you have"}

df.dropna(inplace=True)
def cont_to_exp(x):
    if type(x) is str:
        x = x.replace('//','')
        for key in contractions:
            value = contractions[key]
            x = x.replace(key, value)
        return x
    else: 
        return x
df['review'] = df['review'].apply(lambda x:cont_to_exp)
df.head()
